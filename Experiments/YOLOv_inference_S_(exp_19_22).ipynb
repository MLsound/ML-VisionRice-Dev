# %% [markdown]
# # Experiments 19-22 (640 px) - _Inference on S size_
#
# - **Model:**
#     1. `yolov8m` *(Medium)*
#     2. `yolov9m` *(Medium)*
#     3. `yolov11m` *(Medium)*
#     4. `yolov12m` *(Medium)*
# - **Dataset:** 3.5m | 90º
# - **Crop Tiles:** 640px
# - **Sizes:** small & mid
# - **Experiments:**
#     - Inferencia sobre imagen de `planta chica` (S) con cada modelo _Medium_ (1-4)

# %% [markdown]
# ### Init

# %%
import os
import shutil
import fnmatch
import pandas as pd

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.86-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.86-py3-none-any.whl (922 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.6/922.6 kB 54.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.86 ultralytics-thop-2.0.14

# %% [markdown]
# ## Helper Functions

# %%
def label_to_str(export: pd.DataFrame) -> list[str]:

    """
    Converts each row of a dataframe into string format

    Parameters:
    - Dataframe with labels (np.dataframe)

    Returns:
    - List with labels in text (list[str])
    """

    lines = []
    for _, row in export.iterrows():
        row_list = list(row)
        row_list[0] = int(row_list[0])
        line = ' '.join(map(str, row_list))
        lines.append(line)

    # Verificar que la cantidad de lineas coincide con la cantidad de labels
    if not len(lines) == len(export):
        raise ValueError("🚨 CUIDADO: el número de etiquetas en el archivo de salida y el dataframe no coinciden.")

    return lines

# %%
# Change for different file formats
reference = {
  "small": {
    "suffix": ".S",
    "file": "209"
  },
  "mid": {
    "suffix": ".M",
    "file": "503"
  },
  "large": {
    "suffix": ".L",
    "file": "000"
  }
}

# %%
# Clone config files
def copy_config(src_folder, dest_folder):
    """
    Copies files from src_folder to dest_folder, excluding subfolders.

    Args:
        src_folder: The path to the source folder.
        dest_folder: The path to the destination folder.
    """

    try:
        # Ensure destination folder exists
        os.makedirs(dest_folder, exist_ok=True)

        for filename in os.listdir(src_folder):
            src_path = os.path.join(src_folder, filename)
            dest_path = os.path.join(dest_folder, filename)

            if os.path.isfile(src_path):
                shutil.copy2(src_path, dest_path) #copy metadata as well.
                #Use shutil.copy for not copying metadata.
                print(f"Copied: {filename}")
            #else: #optional
                #print(f"Skipped (not a file): {filename}") #optional. Uncomment if you want to see the skipped folders.

        print("✅ Copying complete.")

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %%
# Copy filtered dataset images/labels
def copy_and_filter_folder(src_folder, dest_folder, pattern):
    """
    Copies a folder and files that match the given pattern.
    Alerts the user when a folder or file already exists but *does not* overwrite.
    Creates only what is needed.

    :param src_folder: Path to the source folder.
    :param dest_folder: Path to the destination folder.
    :param pattern: Filename pattern to keep (e.g., "*.txt").
    """
    try:
        # Ensure destination folder exists
        if not os.path.exists(dest_folder):
            print(f"✓ Creating destination folder '{dest_folder}'.\n")
            os.makedirs(dest_folder)
        else:
            print(f"✓ Destination folder '{dest_folder}' already exists.\n")

        # Walk through the source folder
        for root, _, files in os.walk(src_folder):
            relative_path = os.path.relpath(root, src_folder)
            new_root = os.path.join(dest_folder, relative_path)

            if not os.path.exists(new_root):
                print(f"Creating subdirectory '{new_root}'")
                os.makedirs(new_root)
            else:
                print(f"❕Subdirectory '{new_root}' already exists.")
                print("Make sure the data inside is relevant. Otherwise, just delete the folder and repeat the cloning process.")

            for file in files:
                if fnmatch.fnmatch(file, pattern + "*"):
                    src_file = os.path.join(root, file)
                    dest_file = os.path.join(new_root, file)

                    if not os.path.exists(dest_file):
                        shutil.copy2(src_file, dest_file)  # copy metadata as well
                    else:
                        print(f"❗️File '{dest_file}' already exists. Skipping.")

            print(f" ✓ Copying files complete.\n")
        print("✅ Copying dataset complete.")

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %%
def copy_directory(source, destination, overwrite=True):
    try:
        if overwrite and os.path.exists(destination):
            shutil.rmtree(destination)  # Remove existing directory
        shutil.copytree(source, destination)
        print(f"Directory '{source}' copied to '{destination}'")
        return True  # Indicate success
    except FileExistsError:
        print(f"Destination '{destination}' exists. Use overwrite=True to replace.")
        return False  # Indicate failure

# %%
import pickle

def save_results(results, filename, verbose = True):
    output_file = f"{filename}.pkl"
    with open(output_file, 'wb') as f:
        pickle.dump(results, f)

    if verbose:
      print(f"✅ Results saved as PKL to {output_file}")

def load_results(filename, verbose = True):
    with open(filename, 'rb') as f:
        return pickle.load(f)

    if verbose:
      print(f"✅ Results loaded as PKL from {filename}")

# %%
import json

def serialize_results(obj):
    if isinstance(obj, YOLO):
        return str(obj)  # Convert YOLO model object to string representation
    elif hasattr(obj, 'tolist'):  # Check if object has tolist() method (e.g., NumPy arrays, tensors)
        return obj.tolist()
    elif isinstance(obj, (str, int, float, bool, type(None))):
        return obj  # Directly serialize basic types
    else:
        try:
            # Attempt to convert object to dictionary if possible
            return obj.__dict__
        except AttributeError:
            raise TypeError(f"Object of type {type(obj).__name__} is not JSON serializable")

def save_as_json(results, filename="results.json", verbose = True):
    output_file = f"{filename}.json"
    serialized_results = []
    for result in results:
        serialized_result = {
            "path": result.path,
            "names": result.names,
            "boxes": serialize_results(result.boxes),
            "masks": serialize_results(result.masks),
            "probs": serialize_results(result.probs),
            "keypoints": serialize_results(result.keypoints),
            "speed": result.speed  # Assuming speed is already JSON serializable
        }
        serialized_results.append(serialized_result)

    with open(output_file, "w") as f:
        json.dump(serialized_results, f, default=serialize_results, indent=4)

    if verbose:
      print(f"✅ Results saved as JSON to {output_file}")

# %%
def save_bboxes(results, filename, verbose = True):
    """
    Convierte los resultados de bounding boxes de YOLO a formato COCO TXT.

    Args:
        results (ultralytics.engine.results.Results): Resultados de la inferencia de YOLO.
        output_file (str): Ruta al archivo TXT de salida.
    """
    output_file = f"{filename}.txt"
    with open(output_file, 'w') as f:
        for result in results:
            if result.boxes:
                boxes = result.boxes.xywhn.tolist() # Obtener bounding boxes normalizados (xywhn)
                classes = result.boxes.cls.tolist() # Obtener clases.
                for box, cls in zip(boxes, classes):
                    x_center, y_center, width, height = box
                    f.write(f"{int(cls)} {x_center} {y_center} {width} {height}\n")

    if verbose:
      print(f"✅ Results saved as TXT to {output_file}")

# %%
def save_on_cloud(source: str, destination: str):
    """
    Saves a folder to a cloud storage location (e.g., Google Drive in Colab).

    Args:
        source (str): The path to the source folder.
        destination (str): The path to the destination folder (in cloud storage).
    """
    # 0. Input Validation (Assertions)
    assert isinstance(source, str), "Source must be a string."
    assert isinstance(destination, str), "Destination must be a string."

    try:
        # 1. Verify Source Folder
        if not os.path.exists(destination):
            os.makedirs(destination)

        # 2. Copy the Folder
        shutil.copytree(source, destination, dirs_exist_ok=True)
        print("✅ Folder copied successfully:\n  ",source,"\n  -->",destination)

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %% [markdown]
# # Datasets builder

# %% [markdown]
# ## Importing from Drive
# Se realizará la carga de cada tile de la imagen desde la carpeta inference

# %%
# !rm -rf /content/sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check if the cloud path is ok and the dataset can be found
# !ls /content/drive/MyDrive/YOLO
# Out:
# 3.5m.v3i.yolov8.640px  Inference  models

# %% [markdown]
# A modo de prueba, se cargarán las imagenes pre-procesadas y dividadas en mosaicos.

# %%
drive_path = '/content/drive/MyDrive/YOLO/Inference/'
drive_datasets_paths = os.listdir(drive_path)
drive_datasets = len(drive_datasets_paths)
if (drive_datasets) > 1:
    print("There are %d dataset options:" % drive_datasets)
else:
    print("Theres is only 1 dataset:")
drive_datasets_paths
# Out:
# There are 2 dataset options:
# ['S', 'M']

# %%
choose_dataset = 1
index = choose_dataset - 1
model = os.listdir(drive_path)[index]
print("Choosed dataset:", model)
# Out:
# Choosed dataset: S

# %% [markdown]
# ***Readme:***
# *   **Option 1:** is desirable if you need to test many subset combinations in the same session (avoid downloading data twice from the cloud).
# *   **Option 2:** is desired if you are goint to work just with one dataset  (avoid downloading unnecessary data from the cloud).
# *   **Option 3:** is best if you're just going to test one subset combination  (avoid downloading any data from the cloud).

# %%
# Option 1 (download all datasets)
# !cp -r /content/drive/MyDrive/YOLO/ /content
src_folder = f"/content/YOLO/{model}"

# %%
# Option 2 (download just the needed dataset)
cloud_path = f"/content/drive/MyDrive/YOLO/Inference/{model}/"
local_path = f"/content/YOLO/Inference/"
# !mkdir "/content/YOLO/"
# !mkdir $local_path
# !cp -r $cloud_path $local_path
src_folder = f"/content/YOLO/Inference/{model}"
# Out:
# mkdir: cannot create directory ‘/content/YOLO/’: File exists
# mkdir: cannot create directory ‘/content/YOLO/Inference/’: File exists

# %%
# Option 3 (don't download it, just open it from the cloud)
src_folder = f"{drive_path}/{model}"

# %% [markdown]
# # Carga de modelos entrenados

# %%
from ultralytics import YOLO

# %%
models = []

# %%
# Load best YOLOv8 stored model
model1 = YOLO("/content/drive/MyDrive/YOLO/models/best8.pt")
models.append(model1)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv9 stored model
model2 = YOLO("/content/drive/MyDrive/YOLO/models/best9.pt")
models.append(model2)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv11 stored model
model3 = YOLO("/content/drive/MyDrive/YOLO/models/best11.pt")
models.append(model3)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv12 stored model
model4 = YOLO("/content/drive/MyDrive/YOLO/models/best12.pt")
models.append(model4)
# Medium | 640px | 1000epoch + early

# %%
#models = [model1, model2, model3, model4]
print(f"Se han cargado un total de {len(models)} modelos.")
# Out:
# Se han cargado un total de 4 modelos.

# %% [markdown]
# # Inference
# Se realizarán las inferencias para cada imagen de forma iterativa (con cada modelo)

# %%
experiment="experiment1"
print("Experimento: ", experiment)
print("Source:", src_folder)
# Out:
# Experimento:  experiment1
# Source: /content/YOLO/Inference/S

# %%
files_paths = os.listdir(src_folder)
files_paths.sort()
total_files = len(files_paths)
print(f'Se detectaron un total de {total_files} imágenes:\n')
files_paths
# Out:
# Se detectaron un total de 54 imágenes:
# ['209_205_50_JPG.tile00x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile00x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile01x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile02x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile03x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile04x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg',
#  '209_205_50_JPG.tile05x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg']

# %%
import time

def start_stopwatch():
  start_time = time.time()  # Momento de inicio
  return start_time

def end_stopwatch(start_time):
  end_time = time.time()  # Momento de fin
  return end_time - start_time  # Calcula el tiempo de ejecución

# %%
def count_plants(model, file_name, verbose=False):
  count: int = 0

  # Realiza inferencia para la imagen
  image = f"{src_folder}/{file_name}"
  results = model(image, save=True, project=project, name=experiment, verbose=verbose)

  # Acceder a las coordenadas de los bounding boxes
  for result in results:
      print(result.verbose()) if verbose else ''
      for box in result.boxes:
          count +=1

  # Se almacena cada inferencia como JSON y PKL (log)
  file = os.path.splitext(file_name)[0]
  save_as = f"/content/{project}/{experiment}/inference.{file}"
  save_results(results, save_as, verbose = verbose)
  save_as_json(results, save_as, verbose = verbose)
  save_bboxes(results, save_as, verbose = verbose)

  return count

# %%
import os
import cv2

def count_plants(model, file_name, verbose=False):
  count: int = 0

  # Realiza inferencia para la imagen
  image_path = os.path.join(src_folder, file_name)  # Use os.path.join for platform compatibility

  # Validate image before processing
  if not os.path.exists(image_path):
    print(f"WARNING ⚠️ Image file not found: {image_path}")
    return 0  # Skip if file not found

  try:
    image = cv2.imread(image_path)  # Read image using cv2.imread directly
    if image is None:
      print(f"WARNING ⚠️ Image Read Error {image_path}")
      return 0  # Skip if image could not be read
    results = model(image, save=True, project=project, name=experiment, verbose=verbose)
  except Exception as e:
    print(f"Error processing image {image_path}: {e}")
    return 0  # Skip if any error occurs

  # Acceder a las coordenadas de los bounding boxes
  for result in results:
      print(result.verbose()) if verbose else ''
      for box in result.boxes:
          count +=1

  # Se almacena cada inferencia como JSON y PKL (log)
  file = os.path.splitext(file_name)[0]
  save_as = f"/content/{project}/{experiment}/inference.{file}"
  save_results(results, save_as, verbose = verbose)
  save_as_json(results, save_as, verbose = verbose)
  save_bboxes(results, save_as, verbose = verbose)

  return count

# %%
# Ejecución en batch para todos los mosaicos
verbose = False # Activar para incluir más información sobre almacenamiento de predicciones
total_time = []
total_count = []
model = None
plant_count = 0
for count, file_name in enumerate(files_paths):

    print(f"❇️ Procesado {round((count+1)/total_files*100,3):.2f}%\n") if count > 0 else ''
    print(f"INFERENCE {count+1}/{total_files}:\n {file_name}")
    print()
    infer_time = []
    infer_count = []

    for index, model in enumerate(models):

        # Setup del entrenamiento
        project= f"model{index}"
        print(f"Proyecto: {project}")
        timer = start_stopwatch() # Inicia medición de tiempo
        plant_count = count_plants(model, file_name,) # Ejecuta la inferencia y guarda los datos
        measured_time = end_stopwatch(timer) # Termina medición de tiempo
        print(f"  Tiempo de inferencia {(measured_time*1000):.4} ms")
        print(f"  Se detectaron {plant_count} objetos plant-weed.")
        infer_time.append(measured_time) # Acumula el histórico de rendimiento
        infer_count.append(plant_count) # Acumula el histórico del conteo
        print()

    total_time.append(infer_time)
    total_count.append(infer_count)
    print() if verbose else ''

df_count = pd.DataFrame(total_count)
df_time = pd.DataFrame(total_time)
print(f"✅ EJECUCIÓN COMPLETA\n")

count_sums = df_count.sum().values
time_sums = df_time.sum().values

print("Totales por modelo:")
for index, (time_, count_) in enumerate(zip(time_sums, count_sums)):
    print(f"  Modelo {index + 1} ({float(time_):.2f} seg): {int(count_)}")
print()
# Out:
# INFERENCE 1/54:
#  209_205_50_JPG.tile00x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment1
#   Tiempo de inferencia 60.54 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment1
#   Tiempo de inferencia 62.22 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment1
#   Tiempo de inferencia 59.86 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment1
#   Tiempo de inferencia 69.92 ms
#   Se detectaron 69 objetos plant-weed.
#
# ❇️ Procesado 3.70%
#
# INFERENCE 2/54:
#  209_205_50_JPG.tile00x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment12
#   Tiempo de inferencia 58.0 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment12
#   Tiempo de inferencia 49.53 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment12
#   Tiempo de inferencia 47.71 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment12
#   Tiempo de inferencia 57.67 ms
#   Se detectaron 62 objetos plant-weed.
#
# ❇️ Procesado 5.56%
#
# INFERENCE 3/54:
#  209_205_50_JPG.tile00x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment13
#   Tiempo de inferencia 42.82 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment13
#   Tiempo de inferencia 42.55 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment13
#   Tiempo de inferencia 41.37 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment13
#   Tiempo de inferencia 46.63 ms
#   Se detectaron 41 objetos plant-weed.
#
# ❇️ Procesado 7.41%
#
# INFERENCE 4/54:
#  209_205_50_JPG.tile00x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment14
#   Tiempo de inferencia 38.66 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment14
#   Tiempo de inferencia 45.63 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment14
#   Tiempo de inferencia 40.39 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment14
#   Tiempo de inferencia 45.68 ms
#   Se detectaron 42 objetos plant-weed.
#
# ❇️ Procesado 9.26%
#
# INFERENCE 5/54:
#  209_205_50_JPG.tile00x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment15
#   Tiempo de inferencia 38.57 ms
#   Se detectaron 14 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment15
#   Tiempo de inferencia 43.62 ms
#   Se detectaron 17 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment15
#   Tiempo de inferencia 41.62 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment15
#   Tiempo de inferencia 44.41 ms
#   Se detectaron 33 objetos plant-weed.
#
# ❇️ Procesado 11.11%
#
# INFERENCE 6/54:
#  209_205_50_JPG.tile00x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment16
#   Tiempo de inferencia 37.5 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment16
#   Tiempo de inferencia 39.61 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment16
#   Tiempo de inferencia 42.37 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment16
#   Tiempo de inferencia 47.74 ms
#   Se detectaron 35 objetos plant-weed.
#
# ❇️ Procesado 12.96%
#
# INFERENCE 7/54:
#  209_205_50_JPG.tile00x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment17
#   Tiempo de inferencia 41.94 ms
#   Se detectaron 16 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment17
#   Tiempo de inferencia 41.33 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment17
#   Tiempo de inferencia 39.03 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment17
#   Tiempo de inferencia 44.19 ms
#   Se detectaron 39 objetos plant-weed.
#
# ❇️ Procesado 14.81%
#
# INFERENCE 8/54:
#  209_205_50_JPG.tile00x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment18
#   Tiempo de inferencia 37.17 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment18
#   Tiempo de inferencia 39.97 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment18
#   Tiempo de inferencia 40.45 ms
#   Se detectaron 48 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment18
#   Tiempo de inferencia 46.91 ms
#   Se detectaron 44 objetos plant-weed.
#
# ❇️ Procesado 16.67%
#
# INFERENCE 9/54:
#  209_205_50_JPG.tile00x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment19
#   Tiempo de inferencia 34.51 ms
#   Se detectaron 17 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment19
#   Tiempo de inferencia 37.59 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment19
#   Tiempo de inferencia 37.63 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment19
#   Tiempo de inferencia 45.21 ms
#   Se detectaron 37 objetos plant-weed.
#
# ❇️ Procesado 18.52%
#
# INFERENCE 10/54:
#  209_205_50_JPG.tile01x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment110
#   Tiempo de inferencia 36.64 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment110
#   Tiempo de inferencia 40.78 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment110
#   Tiempo de inferencia 43.87 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment110
#   Tiempo de inferencia 49.66 ms
#   Se detectaron 51 objetos plant-weed.
#
# ❇️ Procesado 20.37%
#
# INFERENCE 11/54:
#  209_205_50_JPG.tile01x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment111
#   Tiempo de inferencia 39.96 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment111
#   Tiempo de inferencia 50.75 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment111
#   Tiempo de inferencia 48.1 ms
#   Se detectaron 56 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment111
#   Tiempo de inferencia 48.9 ms
#   Se detectaron 70 objetos plant-weed.
#
# ❇️ Procesado 22.22%
#
# INFERENCE 12/54:
#  209_205_50_JPG.tile01x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment112
#   Tiempo de inferencia 39.84 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment112
#   Tiempo de inferencia 44.27 ms
#   Se detectaron 55 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment112
#   Tiempo de inferencia 44.86 ms
#   Se detectaron 66 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment112
#   Tiempo de inferencia 54.66 ms
#   Se detectaron 97 objetos plant-weed.
#
# ❇️ Procesado 24.07%
#
# INFERENCE 13/54:
#  209_205_50_JPG.tile01x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment113
#   Tiempo de inferencia 36.15 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment113
#   Tiempo de inferencia 37.35 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment113
#   Tiempo de inferencia 38.64 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment113
#   Tiempo de inferencia 46.51 ms
#   Se detectaron 37 objetos plant-weed.
#
# ❇️ Procesado 25.93%
#
# INFERENCE 14/54:
#  209_205_50_JPG.tile01x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment114
#   Tiempo de inferencia 36.06 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment114
#   Tiempo de inferencia 39.8 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment114
#   Tiempo de inferencia 40.17 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment114
#   Tiempo de inferencia 47.28 ms
#   Se detectaron 47 objetos plant-weed.
#
# ❇️ Procesado 27.78%
#
# INFERENCE 15/54:
#  209_205_50_JPG.tile01x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment115
#   Tiempo de inferencia 38.91 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment115
#   Tiempo de inferencia 43.41 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment115
#   Tiempo de inferencia 41.54 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment115
#   Tiempo de inferencia 46.9 ms
#   Se detectaron 54 objetos plant-weed.
#
# ❇️ Procesado 29.63%
#
# INFERENCE 16/54:
#  209_205_50_JPG.tile01x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment116
#   Tiempo de inferencia 40.81 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment116
#   Tiempo de inferencia 38.24 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment116
#   Tiempo de inferencia 49.21 ms
#   Se detectaron 41 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment116
#   Tiempo de inferencia 46.55 ms
#   Se detectaron 50 objetos plant-weed.
#
# ❇️ Procesado 31.48%
#
# INFERENCE 17/54:
#  209_205_50_JPG.tile01x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment117
#   Tiempo de inferencia 43.14 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment117
#   Tiempo de inferencia 54.63 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment117
#   Tiempo de inferencia 47.6 ms
#   Se detectaron 67 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment117
#   Tiempo de inferencia 53.46 ms
#   Se detectaron 69 objetos plant-weed.
#
# ❇️ Procesado 33.33%
#
# INFERENCE 18/54:
#  209_205_50_JPG.tile01x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment118
#   Tiempo de inferencia 34.77 ms
#   Se detectaron 17 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment118
#   Tiempo de inferencia 39.21 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment118
#   Tiempo de inferencia 38.62 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment118
#   Tiempo de inferencia 44.68 ms
#   Se detectaron 36 objetos plant-weed.
#
# ❇️ Procesado 35.19%
#
# INFERENCE 19/54:
#  209_205_50_JPG.tile02x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment119
#   Tiempo de inferencia 40.16 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment119
#   Tiempo de inferencia 42.82 ms
#   Se detectaron 48 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment119
#   Tiempo de inferencia 44.86 ms
#   Se detectaron 62 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment119
#   Tiempo de inferencia 48.65 ms
#   Se detectaron 69 objetos plant-weed.
#
# ❇️ Procesado 37.04%
#
# INFERENCE 20/54:
#  209_205_50_JPG.tile02x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment120
#   Tiempo de inferencia 38.14 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment120
#   Tiempo de inferencia 43.92 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment120
#   Tiempo de inferencia 42.26 ms
#   Se detectaron 55 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment120
#   Tiempo de inferencia 48.71 ms
#   Se detectaron 55 objetos plant-weed.
#
# ❇️ Procesado 38.89%
#
# INFERENCE 21/54:
#  209_205_50_JPG.tile02x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment121
#   Tiempo de inferencia 40.12 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment121
#   Tiempo de inferencia 40.83 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment121
#   Tiempo de inferencia 40.76 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment121
#   Tiempo de inferencia 46.63 ms
#   Se detectaron 42 objetos plant-weed.
#
# ❇️ Procesado 40.74%
#
# INFERENCE 22/54:
#  209_205_50_JPG.tile02x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment122
#   Tiempo de inferencia 42.38 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment122
#   Tiempo de inferencia 47.0 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment122
#   Tiempo de inferencia 44.13 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment122
#   Tiempo de inferencia 57.48 ms
#   Se detectaron 55 objetos plant-weed.
#
# ❇️ Procesado 42.59%
#
# INFERENCE 23/54:
#  209_205_50_JPG.tile02x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment123
#   Tiempo de inferencia 39.34 ms
#   Se detectaron 32 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment123
#   Tiempo de inferencia 40.28 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment123
#   Tiempo de inferencia 39.17 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment123
#   Tiempo de inferencia 47.1 ms
#   Se detectaron 51 objetos plant-weed.
#
# ❇️ Procesado 44.44%
#
# INFERENCE 24/54:
#  209_205_50_JPG.tile02x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment124
#   Tiempo de inferencia 38.94 ms
#   Se detectaron 20 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment124
#   Tiempo de inferencia 41.93 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment124
#   Tiempo de inferencia 41.85 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment124
#   Tiempo de inferencia 65.51 ms
#   Se detectaron 41 objetos plant-weed.
#
# ❇️ Procesado 46.30%
#
# INFERENCE 25/54:
#  209_205_50_JPG.tile02x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment125
#   Tiempo de inferencia 47.66 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment125
#   Tiempo de inferencia 44.18 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment125
#   Tiempo de inferencia 43.63 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment125
#   Tiempo de inferencia 47.82 ms
#   Se detectaron 42 objetos plant-weed.
#
# ❇️ Procesado 48.15%
#
# INFERENCE 26/54:
#  209_205_50_JPG.tile02x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment126
#   Tiempo de inferencia 39.24 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment126
#   Tiempo de inferencia 42.49 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment126
#   Tiempo de inferencia 43.43 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment126
#   Tiempo de inferencia 47.45 ms
#   Se detectaron 46 objetos plant-weed.
#
# ❇️ Procesado 50.00%
#
# INFERENCE 27/54:
#  209_205_50_JPG.tile02x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment127
#   Tiempo de inferencia 42.4 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment127
#   Tiempo de inferencia 40.39 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment127
#   Tiempo de inferencia 43.48 ms
#   Se detectaron 41 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment127
#   Tiempo de inferencia 49.61 ms
#   Se detectaron 48 objetos plant-weed.
#
# ❇️ Procesado 51.85%
#
# INFERENCE 28/54:
#  209_205_50_JPG.tile03x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment128
#   Tiempo de inferencia 50.28 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment128
#   Tiempo de inferencia 51.59 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment128
#   Tiempo de inferencia 47.85 ms
#   Se detectaron 49 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment128
#   Tiempo de inferencia 51.36 ms
#   Se detectaron 58 objetos plant-weed.
#
# ❇️ Procesado 53.70%
#
# INFERENCE 29/54:
#  209_205_50_JPG.tile03x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment129
#   Tiempo de inferencia 42.05 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment129
#   Tiempo de inferencia 43.28 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment129
#   Tiempo de inferencia 44.61 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment129
#   Tiempo de inferencia 52.05 ms
#   Se detectaron 71 objetos plant-weed.
#
# ❇️ Procesado 55.56%
#
# INFERENCE 30/54:
#  209_205_50_JPG.tile03x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment130
#   Tiempo de inferencia 38.56 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment130
#   Tiempo de inferencia 43.1 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment130
#   Tiempo de inferencia 40.63 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment130
#   Tiempo de inferencia 48.77 ms
#   Se detectaron 40 objetos plant-weed.
#
# ❇️ Procesado 57.41%
#
# INFERENCE 31/54:
#  209_205_50_JPG.tile03x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment131
#   Tiempo de inferencia 43.42 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment131
#   Tiempo de inferencia 42.16 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment131
#   Tiempo de inferencia 43.39 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment131
#   Tiempo de inferencia 49.87 ms
#   Se detectaron 52 objetos plant-weed.
#
# ❇️ Procesado 59.26%
#
# INFERENCE 32/54:
#  209_205_50_JPG.tile03x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment132
#   Tiempo de inferencia 40.98 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment132
#   Tiempo de inferencia 44.44 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment132
#   Tiempo de inferencia 42.77 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment132
#   Tiempo de inferencia 50.02 ms
#   Se detectaron 48 objetos plant-weed.
#
# ❇️ Procesado 61.11%
#
# INFERENCE 33/54:
#  209_205_50_JPG.tile03x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment133
#   Tiempo de inferencia 37.83 ms
#   Se detectaron 17 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment133
#   Tiempo de inferencia 41.62 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment133
#   Tiempo de inferencia 43.21 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment133
#   Tiempo de inferencia 72.45 ms
#   Se detectaron 31 objetos plant-weed.
#
# ❇️ Procesado 62.96%
#
# INFERENCE 34/54:
#  209_205_50_JPG.tile03x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment134
#   Tiempo de inferencia 48.43 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment134
#   Tiempo de inferencia 44.96 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment134
#   Tiempo de inferencia 48.55 ms
#   Se detectaron 53 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment134
#   Tiempo de inferencia 52.6 ms
#   Se detectaron 63 objetos plant-weed.
#
# ❇️ Procesado 64.81%
#
# INFERENCE 35/54:
#  209_205_50_JPG.tile03x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment135
#   Tiempo de inferencia 42.95 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment135
#   Tiempo de inferencia 48.05 ms
#   Se detectaron 47 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment135
#   Tiempo de inferencia 47.64 ms
#   Se detectaron 60 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment135
#   Tiempo de inferencia 57.05 ms
#   Se detectaron 84 objetos plant-weed.
#
# ❇️ Procesado 66.67%
#
# INFERENCE 36/54:
#  209_205_50_JPG.tile03x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment136
#   Tiempo de inferencia 37.45 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment136
#   Tiempo de inferencia 40.26 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment136
#   Tiempo de inferencia 42.83 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment136
#   Tiempo de inferencia 51.49 ms
#   Se detectaron 31 objetos plant-weed.
#
# ❇️ Procesado 68.52%
#
# INFERENCE 37/54:
#  209_205_50_JPG.tile04x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment137
#   Tiempo de inferencia 44.2 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment137
#   Tiempo de inferencia 43.23 ms
#   Se detectaron 20 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment137
#   Tiempo de inferencia 39.34 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment137
#   Tiempo de inferencia 43.72 ms
#   Se detectaron 32 objetos plant-weed.
#
# ❇️ Procesado 70.37%
#
# INFERENCE 38/54:
#  209_205_50_JPG.tile04x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment138
#   Tiempo de inferencia 40.53 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment138
#   Tiempo de inferencia 44.85 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment138
#   Tiempo de inferencia 47.07 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment138
#   Tiempo de inferencia 48.45 ms
#   Se detectaron 58 objetos plant-weed.
#
# ❇️ Procesado 72.22%
#
# INFERENCE 39/54:
#  209_205_50_JPG.tile04x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment139
#   Tiempo de inferencia 42.39 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment139
#   Tiempo de inferencia 52.5 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment139
#   Tiempo de inferencia 44.9 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment139
#   Tiempo de inferencia 50.66 ms
#   Se detectaron 60 objetos plant-weed.
#
# ❇️ Procesado 74.07%
#
# INFERENCE 40/54:
#  209_205_50_JPG.tile04x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment140
#   Tiempo de inferencia 40.2 ms
#   Se detectaron 17 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment140
#   Tiempo de inferencia 40.28 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment140
#   Tiempo de inferencia 40.07 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment140
#   Tiempo de inferencia 46.32 ms
#   Se detectaron 36 objetos plant-weed.
#
# ❇️ Procesado 75.93%
#
# INFERENCE 41/54:
#  209_205_50_JPG.tile04x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment141
#   Tiempo de inferencia 42.22 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment141
#   Tiempo de inferencia 45.49 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment141
#   Tiempo de inferencia 46.9 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment141
#   Tiempo de inferencia 65.63 ms
#   Se detectaron 45 objetos plant-weed.
#
# ❇️ Procesado 77.78%
#
# INFERENCE 42/54:
#  209_205_50_JPG.tile04x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment142
#   Tiempo de inferencia 49.63 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment142
#   Tiempo de inferencia 53.47 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment142
#   Tiempo de inferencia 52.63 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment142
#   Tiempo de inferencia 65.17 ms
#   Se detectaron 38 objetos plant-weed.
#
# ❇️ Procesado 79.63%
#
# INFERENCE 43/54:
#  209_205_50_JPG.tile04x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment143
#   Tiempo de inferencia 46.09 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment143
#   Tiempo de inferencia 51.15 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment143
#   Tiempo de inferencia 51.05 ms
#   Se detectaron 32 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment143
#   Tiempo de inferencia 56.43 ms
#   Se detectaron 49 objetos plant-weed.
#
# ❇️ Procesado 81.48%
#
# INFERENCE 44/54:
#  209_205_50_JPG.tile04x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment144
#   Tiempo de inferencia 43.8 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment144
#   Tiempo de inferencia 60.17 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment144
#   Tiempo de inferencia 62.13 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment144
#   Tiempo de inferencia 64.61 ms
#   Se detectaron 53 objetos plant-weed.
#
# ❇️ Procesado 83.33%
#
# INFERENCE 45/54:
#  209_205_50_JPG.tile04x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment145
#   Tiempo de inferencia 47.8 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment145
#   Tiempo de inferencia 51.4 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment145
#   Tiempo de inferencia 51.8 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment145
#   Tiempo de inferencia 57.05 ms
#   Se detectaron 35 objetos plant-weed.
#
# ❇️ Procesado 85.19%
#
# INFERENCE 46/54:
#  209_205_50_JPG.tile05x00.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment146
#   Tiempo de inferencia 45.3 ms
#   Se detectaron 20 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment146
#   Tiempo de inferencia 46.64 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment146
#   Tiempo de inferencia 45.51 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment146
#   Tiempo de inferencia 61.2 ms
#   Se detectaron 43 objetos plant-weed.
#
# ❇️ Procesado 87.04%
#
# INFERENCE 47/54:
#  209_205_50_JPG.tile05x01.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment147
#   Tiempo de inferencia 55.04 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment147
#   Tiempo de inferencia 48.55 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment147
#   Tiempo de inferencia 47.39 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment147
#   Tiempo de inferencia 63.4 ms
#   Se detectaron 48 objetos plant-weed.
#
# ❇️ Procesado 88.89%
#
# INFERENCE 48/54:
#  209_205_50_JPG.tile05x02.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment148
#   Tiempo de inferencia 43.61 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment148
#   Tiempo de inferencia 45.74 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment148
#   Tiempo de inferencia 42.87 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment148
#   Tiempo de inferencia 53.92 ms
#   Se detectaron 52 objetos plant-weed.
#
# ❇️ Procesado 90.74%
#
# INFERENCE 49/54:
#  209_205_50_JPG.tile05x03.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment149
#   Tiempo de inferencia 46.49 ms
#   Se detectaron 16 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment149
#   Tiempo de inferencia 47.28 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment149
#   Tiempo de inferencia 47.01 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment149
#   Tiempo de inferencia 54.83 ms
#   Se detectaron 38 objetos plant-weed.
#
# ❇️ Procesado 92.59%
#
# INFERENCE 50/54:
#  209_205_50_JPG.tile05x04.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment150
#   Tiempo de inferencia 41.83 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment150
#   Tiempo de inferencia 45.69 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment150
#   Tiempo de inferencia 48.42 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment150
#   Tiempo de inferencia 55.86 ms
#   Se detectaron 49 objetos plant-weed.
#
# ❇️ Procesado 94.44%
#
# INFERENCE 51/54:
#  209_205_50_JPG.tile05x05.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment151
#   Tiempo de inferencia 47.63 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment151
#   Tiempo de inferencia 44.02 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment151
#   Tiempo de inferencia 52.06 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment151
#   Tiempo de inferencia 89.18 ms
#   Se detectaron 48 objetos plant-weed.
#
# ❇️ Procesado 96.30%
#
# INFERENCE 52/54:
#  209_205_50_JPG.tile05x06.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment152
#   Tiempo de inferencia 61.97 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment152
#   Tiempo de inferencia 46.31 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment152
#   Tiempo de inferencia 49.55 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment152
#   Tiempo de inferencia 56.94 ms
#   Se detectaron 40 objetos plant-weed.
#
# ❇️ Procesado 98.15%
#
# INFERENCE 53/54:
#  209_205_50_JPG.tile05x07.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment153
#   Tiempo de inferencia 45.33 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment153
#   Tiempo de inferencia 49.47 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment153
#   Tiempo de inferencia 53.16 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment153
#   Tiempo de inferencia 77.71 ms
#   Se detectaron 60 objetos plant-weed.
#
# ❇️ Procesado 100.00%
#
# INFERENCE 54/54:
#  209_205_50_JPG.tile05x08.rf.949b5aa6fdbf6a1f721c39ed5ddcebec.jpg
#
# Proyecto: model0
# Results saved to model0/experiment154
#   Tiempo de inferencia 46.0 ms
#   Se detectaron 10 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment154
#   Tiempo de inferencia 54.55 ms
#   Se detectaron 12 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment154
#   Tiempo de inferencia 61.56 ms
#   Se detectaron 13 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment154
#   Tiempo de inferencia 59.53 ms
#   Se detectaron 25 objetos plant-weed.
#
# ✅ EJECUCIÓN COMPLETA
#
# Totales por modelo:
#   Modelo 1 (2.32 seg): 1362
#   Modelo 2 (2.44 seg): 1547
#   Modelo 3 (2.45 seg): 2137
#   Modelo 4 (2.90 seg): 2649

# %%
count_avg = df_count.mean().values
time_avg = df_time.mean().values

print("Promedios por modelo:")
for index, (time_, count_) in enumerate(zip(time_avg, count_avg)):
    print(f"  Modelo {index + 1} ({float(time_*1000):.3f} ms): {float(count_):.1f} obj/image")
print()
# Out:
# Promedios por modelo:
#   Modelo 1 (42.896 ms): 25.2 obj/image
#   Modelo 2 (45.270 ms): 28.6 obj/image
#   Modelo 3 (45.398 ms): 39.6 obj/image
#   Modelo 4 (53.744 ms): 49.1 obj/image

# %% [markdown]
# # Almacenamiento de predicciones

# %%
# Store experiments
# !mkdir /content/drive/MyDrive/Results
for index, model in enumerate(models):
    project= f"model{index}"
    save_on_cloud(source=f'/content/{project}/{experiment}/', destination=f'/content/drive/MyDrive/Results/{project}/{experiment}/')
    print()
# Out:
# ✅ Folder copied successfully:
#    /content/model0/experiment1/
#   --> /content/drive/MyDrive/Results/model0/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model1/experiment1/
#   --> /content/drive/MyDrive/Results/model1/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model2/experiment1/
#   --> /content/drive/MyDrive/Results/model2/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model3/experiment1/
#   --> /content/drive/MyDrive/Results/model3/experiment1/

# %%
# Save execution time log
filenames = [{
    'file': df_time,
    'name': f"{experiment}.total_time.csv"},
     {'file': df_count,
    'name': f"{experiment}.total_count.csv"}
  ]

for filename in filenames:
  try:
      name = filename['name']
      df = filename['file']
      if df is not None:
        df.to_csv(f"/content/{name}")
      print(f"✅ Execution log saved as CSV to {name}")

      source=f'/content/{name}'
      destination='/content/drive/MyDrive/Results/'
      # !cp $source $destination

  except PermissionError:
      print(f"Error: Permission denied. Could not save {name}")
  except OSError as e:
      print(f"Error: An operating system error occurred: {e} when trying to save {name}.")
  except Exception as e:
      print(f"An unexpected error occurred: {e} when trying to save {name}.")
# Out:
# ✅ Execution log saved as CSV to experiment1.total_time.csv
# ✅ Execution log saved as CSV to experiment1.total_count.csv

# %% [markdown]
# # Eliminar archivos de inferencia (en caso de errores)

# %%
proceed = False

# %%
# Removes pervious train (CAUTION)
if proceed:
  for index, model in enumerate(models):
      project= f"model{index}"
      source=f'/content/{project}/'
      # !rm -rf $source

# %%
if proceed:
  file = f"/content/{experiment}.total_count.csv"
  # !rm $file
  file = f"/content/{experiment}.total_time.csv"
  # !rm $file
