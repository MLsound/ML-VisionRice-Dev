# %% [markdown]
# # Experiments 19-22 (640 px) - _Inference on M size_
#
# - **Model:**
#     1. `yolov8m` *(Medium)*
#     2. `yolov9m` *(Medium)*
#     3. `yolov11m` *(Medium)*
#     4. `yolov12m` *(Medium)*
# - **Dataset:** 3.5m | 90º
# - **Sizes:** small & mid
# - **Crop Tiles:** 640px
# - **Experiments:**
#     - Inferencia sobre imagen de `planta mediana` (M) con cada modelo _Medium_ (1-4)

# %% [markdown]
# ### Init

# %%
import os
import shutil
import fnmatch
import pandas as pd

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.11/site-packages (8.3.81)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Helper Functions

# %%
def label_to_str(export: pd.DataFrame) -> list[str]:

    """
    Converts each row of a dataframe into string format

    Parameters:
    - Dataframe with labels (np.dataframe)

    Returns:
    - List with labels in text (list[str])
    """

    lines = []
    for _, row in export.iterrows():
        row_list = list(row)
        row_list[0] = int(row_list[0])
        line = ' '.join(map(str, row_list))
        lines.append(line)

    # Verificar que la cantidad de lineas coincide con la cantidad de labels
    if not len(lines) == len(export):
        raise ValueError("🚨 CUIDADO: el número de etiquetas en el archivo de salida y el dataframe no coinciden.")

    return lines

# %%
# Change for different file formats
reference = {
  "small": {
    "suffix": ".S",
    "file": "209"
  },
  "mid": {
    "suffix": ".M",
    "file": "503"
  },
  "large": {
    "suffix": ".L",
    "file": "000"
  }
}

# %%
# Clone config files
def copy_config(src_folder, dest_folder):
    """
    Copies files from src_folder to dest_folder, excluding subfolders.

    Args:
        src_folder: The path to the source folder.
        dest_folder: The path to the destination folder.
    """

    try:
        # Ensure destination folder exists
        os.makedirs(dest_folder, exist_ok=True)

        for filename in os.listdir(src_folder):
            src_path = os.path.join(src_folder, filename)
            dest_path = os.path.join(dest_folder, filename)

            if os.path.isfile(src_path):
                shutil.copy2(src_path, dest_path) #copy metadata as well.
                #Use shutil.copy for not copying metadata.
                print(f"Copied: {filename}")
            #else: #optional
                #print(f"Skipped (not a file): {filename}") #optional. Uncomment if you want to see the skipped folders.

        print("✅ Copying complete.")

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %%
# Copy filtered dataset images/labels
def copy_and_filter_folder(src_folder, dest_folder, pattern):
    """
    Copies a folder and files that match the given pattern.
    Alerts the user when a folder or file already exists but *does not* overwrite.
    Creates only what is needed.

    :param src_folder: Path to the source folder.
    :param dest_folder: Path to the destination folder.
    :param pattern: Filename pattern to keep (e.g., "*.txt").
    """
    try:
        # Ensure destination folder exists
        if not os.path.exists(dest_folder):
            print(f"✓ Creating destination folder '{dest_folder}'.\n")
            os.makedirs(dest_folder)
        else:
            print(f"✓ Destination folder '{dest_folder}' already exists.\n")

        # Walk through the source folder
        for root, _, files in os.walk(src_folder):
            relative_path = os.path.relpath(root, src_folder)
            new_root = os.path.join(dest_folder, relative_path)

            if not os.path.exists(new_root):
                print(f"Creating subdirectory '{new_root}'")
                os.makedirs(new_root)
            else:
                print(f"❕Subdirectory '{new_root}' already exists.")
                print("Make sure the data inside is relevant. Otherwise, just delete the folder and repeat the cloning process.")

            for file in files:
                if fnmatch.fnmatch(file, pattern + "*"):
                    src_file = os.path.join(root, file)
                    dest_file = os.path.join(new_root, file)

                    if not os.path.exists(dest_file):
                        shutil.copy2(src_file, dest_file)  # copy metadata as well
                    else:
                        print(f"❗️File '{dest_file}' already exists. Skipping.")

            print(f" ✓ Copying files complete.\n")
        print("✅ Copying dataset complete.")

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %%
def copy_directory(source, destination, overwrite=True):
    try:
        if overwrite and os.path.exists(destination):
            shutil.rmtree(destination)  # Remove existing directory
        shutil.copytree(source, destination)
        print(f"Directory '{source}' copied to '{destination}'")
        return True  # Indicate success
    except FileExistsError:
        print(f"Destination '{destination}' exists. Use overwrite=True to replace.")
        return False  # Indicate failure

# %%
import pickle

def save_results(results, filename, verbose = True):
    output_file = f"{filename}.pkl"
    with open(output_file, 'wb') as f:
        pickle.dump(results, f)

    if verbose:
      print(f"✅ Results saved as PKL to {output_file}")

def load_results(filename, verbose = True):
    with open(filename, 'rb') as f:
        return pickle.load(f)

    if verbose:
      print(f"✅ Results loaded as PKL from {filename}")

# %%
import json

def serialize_results(obj):
    if isinstance(obj, YOLO):
        return str(obj)  # Convert YOLO model object to string representation
    elif hasattr(obj, 'tolist'):  # Check if object has tolist() method (e.g., NumPy arrays, tensors)
        return obj.tolist()
    elif isinstance(obj, (str, int, float, bool, type(None))):
        return obj  # Directly serialize basic types
    else:
        try:
            # Attempt to convert object to dictionary if possible
            return obj.__dict__
        except AttributeError:
            raise TypeError(f"Object of type {type(obj).__name__} is not JSON serializable")

def save_as_json(results, filename="results.json", verbose = True):
    output_file = f"{filename}.json"
    serialized_results = []
    for result in results:
        serialized_result = {
            "path": result.path,
            "names": result.names,
            "boxes": serialize_results(result.boxes),
            "masks": serialize_results(result.masks),
            "probs": serialize_results(result.probs),
            "keypoints": serialize_results(result.keypoints),
            "speed": result.speed  # Assuming speed is already JSON serializable
        }
        serialized_results.append(serialized_result)

    with open(output_file, "w") as f:
        json.dump(serialized_results, f, default=serialize_results, indent=4)

    if verbose:
      print(f"✅ Results saved as JSON to {output_file}")

# %%
def save_bboxes(results, filename, verbose = True):
    """
    Convierte los resultados de bounding boxes de YOLO a formato COCO TXT.

    Args:
        results (ultralytics.engine.results.Results): Resultados de la inferencia de YOLO.
        output_file (str): Ruta al archivo TXT de salida.
    """
    output_file = f"{filename}.txt"
    with open(output_file, 'w') as f:
        for result in results:
            if result.boxes:
                boxes = result.boxes.xywhn.tolist() # Obtener bounding boxes normalizados (xywhn)
                classes = result.boxes.cls.tolist() # Obtener clases.
                for box, cls in zip(boxes, classes):
                    x_center, y_center, width, height = box
                    f.write(f"{int(cls)} {x_center} {y_center} {width} {height}\n")

    if verbose:
      print(f"✅ Results saved as TXT to {output_file}")

# %%
def save_on_cloud(source: str, destination: str):
    """
    Saves a folder to a cloud storage location (e.g., Google Drive in Colab).

    Args:
        source (str): The path to the source folder.
        destination (str): The path to the destination folder (in cloud storage).
    """
    # 0. Input Validation (Assertions)
    assert isinstance(source, str), "Source must be a string."
    assert isinstance(destination, str), "Destination must be a string."

    try:
        # 1. Verify Source Folder
        if not os.path.exists(destination):
            os.makedirs(destination)

        # 2. Copy the Folder
        shutil.copytree(source, destination, dirs_exist_ok=True)
        print("✅ Folder copied successfully:\n  ",source,"\n  -->",destination)

    except Exception as e:
        print(f"❌ An error occurred: {e}")

# %% [markdown]
# # Datasets builder

# %% [markdown]
# ## Importing from Drive
# Se realizará la carga de cada tile de la imagen desde la carpeta inference

# %%
# !rm -rf /content/sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# A modo de prueba, se cargarán las imagenes pre-procesadas y dividadas en mosaicos.

# %%
drive_path = '/content/drive/MyDrive/YOLO/Inference/'
drive_datasets_paths = os.listdir(drive_path)
drive_datasets = len(drive_datasets_paths)
if (drive_datasets) > 1:
    print("There are %d dataset options:" % drive_datasets)
else:
    print("Theres is only 1 dataset:")
drive_datasets_paths
# Out:
# There are 2 dataset options:
# ['S', 'M']

# %%
choose_dataset = 2
index = choose_dataset - 1
model = os.listdir(drive_path)[index]
print("Chosen dataset:", model)
# Out:
# Chosen dataset: M

# %% [markdown]
# ***Readme:***
# *   **Option 1:** is desirable if you need to test many subset combinations in the same session (avoid downloading data twice from the cloud).
# *   **Option 2:** is desired if you are goint to work just with one dataset  (avoid downloading unnecessary data from the cloud).
# *   **Option 3:** is best if you're just going to test one subset combination  (avoid downloading any data from the cloud).

# %%
# Option 1 (download all datasets)
# !cp -r /content/drive/MyDrive/YOLO/ /content
src_folder = f"/content/YOLO/{model}"

# %%
# Option 2 (download just the needed dataset)
cloud_path = f"/content/drive/MyDrive/YOLO/Inference/{model}/"
local_path = f"/content/YOLO/Inference/"
# !mkdir "/content/YOLO/"
# !mkdir $local_path
# !cp -r $cloud_path $local_path
src_folder = f"/content/YOLO/Inference/{model}"

# %%
# Option 3 (don't download it, just open it from the cloud)
src_folder = f"{drive_path}/{model}"

# %% [markdown]
# # Carga de modelos entrenados

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
models = []

# %%
# Load best YOLOv8 stored model
model1 = YOLO("/content/drive/MyDrive/YOLO/models/best8.pt")
models.append(model1)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv9 stored model
model2 = YOLO("/content/drive/MyDrive/YOLO/models/best9.pt")
models.append(model2)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv11 stored model
model3 = YOLO("/content/drive/MyDrive/YOLO/models/best11.pt")
models.append(model3)
# Medium | 640px | 1000epoch + early

# %%
# Load best YOLOv12 stored model
model4 = YOLO("/content/drive/MyDrive/YOLO/models/best12.pt")
models.append(model4)
# Medium | 640px | 1000epoch + early

# %%
#models = [model1, model2, model3, model4]
print(f"Se han cargado un total de {len(models)} modelos.")
# Out:
# Se han cargado un total de 4 modelos.

# %% [markdown]
# # Inference
# Se realizarán las inferencias para cada imagen de forma iterativa (con cada modelo)

# %%
experiment="experiment2"
print("Experimento: ", experiment)
print("Source:", src_folder)
# Out:
# Experimento:  experiment2
# Source: /content/YOLO/Inference/M

# %%
files_paths = os.listdir(src_folder)
files_paths.sort()
total_files = len(files_paths)
print(f'Se detectaron un total de {total_files} imágenes:\n')
files_paths
# Out:
# Se detectaron un total de 54 imágenes:
# ['tile00x00.503_222_54.640px.jpg',
#  'tile00x01.503_222_54.640px.jpg',
#  'tile00x02.503_222_54.640px.jpg',
#  'tile00x03.503_222_54.640px.jpg',
#  'tile00x04.503_222_54.640px.jpg',
#  'tile00x05.503_222_54.640px.jpg',
#  'tile00x06.503_222_54.640px.jpg',
#  'tile00x07.503_222_54.640px.jpg',
#  'tile00x08.503_222_54.640px.jpg',
#  'tile01x00.503_222_54.640px.jpg',
#  'tile01x01.503_222_54.640px.jpg',
#  'tile01x02.503_222_54.640px.jpg',
#  'tile01x03.503_222_54.640px.jpg',
#  'tile01x04.503_222_54.640px.jpg',
#  'tile01x05.503_222_54.640px.jpg',
#  'tile01x06.503_222_54.640px.jpg',
#  'tile01x07.503_222_54.640px.jpg',
#  'tile01x08.503_222_54.640px.jpg',
#  'tile02x00.503_222_54.640px.jpg',
#  'tile02x01.503_222_54.640px.jpg',
#  'tile02x02.503_222_54.640px.jpg',
#  'tile02x03.503_222_54.640px.jpg',
#  'tile02x04.503_222_54.640px.jpg',
#  'tile02x05.503_222_54.640px.jpg',
#  'tile02x06.503_222_54.640px.jpg',
#  'tile02x07.503_222_54.640px.jpg',
#  'tile02x08.503_222_54.640px.jpg',
#  'tile03x00.503_222_54.640px.jpg',
#  'tile03x01.503_222_54.640px.jpg',
#  'tile03x02.503_222_54.640px.jpg',
#  'tile03x03.503_222_54.640px.jpg',
#  'tile03x04.503_222_54.640px.jpg',
#  'tile03x05.503_222_54.640px.jpg',
#  'tile03x06.503_222_54.640px.jpg',
#  'tile03x07.503_222_54.640px.jpg',
#  'tile03x08.503_222_54.640px.jpg',
#  'tile04x00.503_222_54.640px.jpg',
#  'tile04x01.503_222_54.640px.jpg',
#  'tile04x02.503_222_54.640px.jpg',
#  'tile04x03.503_222_54.640px.jpg',
#  'tile04x04.503_222_54.640px.jpg',
#  'tile04x05.503_222_54.640px.jpg',
#  'tile04x06.503_222_54.640px.jpg',
#  'tile04x07.503_222_54.640px.jpg',
#  'tile04x08.503_222_54.640px.jpg',
#  'tile05x00.503_222_54.640px.jpg',
#  'tile05x01.503_222_54.640px.jpg',
#  'tile05x02.503_222_54.640px.jpg',
#  'tile05x03.503_222_54.640px.jpg',
#  'tile05x04.503_222_54.640px.jpg',
#  'tile05x05.503_222_54.640px.jpg',
#  'tile05x06.503_222_54.640px.jpg',
#  'tile05x07.503_222_54.640px.jpg',
#  'tile05x08.503_222_54.640px.jpg']

# %%
import time

def start_stopwatch():
  start_time = time.time()  # Momento de inicio
  return start_time

def end_stopwatch(start_time):
  end_time = time.time()  # Momento de fin
  return end_time - start_time  # Calcula el tiempo de ejecución

# %%
def count_plants(model, file_name, verbose=False):
  count: int = 0

  # Realiza inferencia para la imagen
  image = f"{src_folder}/{file_name}"
  results = model(image, save=True, project=project, name=experiment, verbose=verbose)

  # Acceder a las coordenadas de los bounding boxes
  for result in results:
      print(result.verbose()) if verbose else ''
      for box in result.boxes:
          count +=1

  # Se almacena cada inferencia como JSON y PKL (log)
  file = os.path.splitext(file_name)[0]
  save_as = f"/content/{project}/{experiment}/inference.{file}"
  save_results(results, save_as, verbose = verbose)
  save_as_json(results, save_as, verbose = verbose)
  save_bboxes(results, save_as, verbose = verbose)

  return count

# %%
import os
import cv2

def count_plants(model, file_name, verbose=False):
  count: int = 0

  # Realiza inferencia para la imagen
  image_path = os.path.join(src_folder, file_name)  # Use os.path.join for platform compatibility

  # Validate image before processing
  if not os.path.exists(image_path):
    print(f"WARNING ⚠️ Image file not found: {image_path}")
    return 0  # Skip if file not found

  try:
    image = cv2.imread(image_path)  # Read image using cv2.imread directly
    if image is None:
      print(f"WARNING ⚠️ Image Read Error {image_path}")
      return 0  # Skip if image could not be read
    results = model(image, save=True, project=project, name=experiment, verbose=verbose)
  except Exception as e:
    print(f"Error processing image {image_path}: {e}")
    return 0  # Skip if any error occurs

  # Acceder a las coordenadas de los bounding boxes
  for result in results:
      print(result.verbose()) if verbose else ''
      for box in result.boxes:
          count +=1

  # Se almacena cada inferencia como JSON y PKL (log)
  file = os.path.splitext(file_name)[0]
  save_as = f"/content/{project}/{experiment}/inference.{file}"
  save_results(results, save_as, verbose = verbose)
  save_as_json(results, save_as, verbose = verbose)
  save_bboxes(results, save_as, verbose = verbose)

  return count

# %%
# Ejecución en batch para todos los mosaicos
verbose = False # Activar para incluir más información sobre almacenamiento de predicciones
total_time = []
total_count = []
model = None
plant_count = 0
for count, file_name in enumerate(files_paths):

    print(f"❇️ Procesado {round((count+1)/total_files*100,3):.2f}%\n") if count > 0 else ''
    print(f"INFERENCE {count+1}/{total_files}:\n {file_name}")
    print()
    infer_time = []
    infer_count = []

    for index, model in enumerate(models):

        # Setup del entrenamiento
        project= f"model{index}"
        print(f"Proyecto: {project}")
        timer = start_stopwatch() # Inicia medición de tiempo
        plant_count = count_plants(model, file_name,) # Ejecuta la inferencia y guarda los datos
        measured_time = end_stopwatch(timer) # Termina medición de tiempo
        print(f"  Tiempo de inferencia {(measured_time*1000):.4} ms")
        print(f"  Se detectaron {plant_count} objetos plant-weed.")
        infer_time.append(measured_time) # Acumula el histórico de rendimiento
        infer_count.append(plant_count) # Acumula el histórico del conteo
        print()

    total_time.append(infer_time)
    total_count.append(infer_count)
    print() if verbose else ''

df_count = pd.DataFrame(total_count)
df_time = pd.DataFrame(total_time)
print(f"✅ EJECUCIÓN COMPLETA\n")

count_sums = df_count.sum().values
time_sums = df_time.sum().values

print("Totales por modelo:")
for index, (time_, count_) in enumerate(zip(time_sums, count_sums)):
    print(f"  Modelo {index + 1} ({float(time_):.2f} seg): {int(count_)}")
print()
# Out:
# INFERENCE 1/54:
#  tile00x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment2
#   Tiempo de inferencia 5.107e+03 ms
#   Se detectaron 50 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment2
#   Tiempo de inferencia 719.4 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment2
#   Tiempo de inferencia 642.5 ms
#   Se detectaron 47 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment2
#   Tiempo de inferencia 465.7 ms
#   Se detectaron 130 objetos plant-weed.
#
# ❇️ Procesado 3.70%
#
# INFERENCE 2/54:
#  tile00x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment22
#   Tiempo de inferencia 52.29 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment22
#   Tiempo de inferencia 57.04 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment22
#   Tiempo de inferencia 54.85 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment22
#   Tiempo de inferencia 58.6 ms
#   Se detectaron 73 objetos plant-weed.
#
# ❇️ Procesado 5.56%
#
# INFERENCE 3/54:
#  tile00x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment23
#   Tiempo de inferencia 45.79 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment23
#   Tiempo de inferencia 54.77 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment23
#   Tiempo de inferencia 54.32 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment23
#   Tiempo de inferencia 53.65 ms
#   Se detectaron 61 objetos plant-weed.
#
# ❇️ Procesado 7.41%
#
# INFERENCE 4/54:
#  tile00x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment24
#   Tiempo de inferencia 37.22 ms
#   Se detectaron 16 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment24
#   Tiempo de inferencia 40.92 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment24
#   Tiempo de inferencia 40.52 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment24
#   Tiempo de inferencia 56.39 ms
#   Se detectaron 53 objetos plant-weed.
#
# ❇️ Procesado 9.26%
#
# INFERENCE 5/54:
#  tile00x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment25
#   Tiempo de inferencia 36.84 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment25
#   Tiempo de inferencia 41.61 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment25
#   Tiempo de inferencia 38.9 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment25
#   Tiempo de inferencia 50.35 ms
#   Se detectaron 56 objetos plant-weed.
#
# ❇️ Procesado 11.11%
#
# INFERENCE 6/54:
#  tile00x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment26
#   Tiempo de inferencia 38.63 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment26
#   Tiempo de inferencia 40.58 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment26
#   Tiempo de inferencia 43.09 ms
#   Se detectaron 32 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment26
#   Tiempo de inferencia 48.54 ms
#   Se detectaron 47 objetos plant-weed.
#
# ❇️ Procesado 12.96%
#
# INFERENCE 7/54:
#  tile00x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment27
#   Tiempo de inferencia 43.12 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment27
#   Tiempo de inferencia 41.74 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment27
#   Tiempo de inferencia 41.24 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment27
#   Tiempo de inferencia 52.34 ms
#   Se detectaron 74 objetos plant-weed.
#
# ❇️ Procesado 14.81%
#
# INFERENCE 8/54:
#  tile00x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment28
#   Tiempo de inferencia 37.48 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment28
#   Tiempo de inferencia 40.16 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment28
#   Tiempo de inferencia 38.88 ms
#   Se detectaron 26 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment28
#   Tiempo de inferencia 54.95 ms
#   Se detectaron 79 objetos plant-weed.
#
# ❇️ Procesado 16.67%
#
# INFERENCE 9/54:
#  tile00x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment29
#   Tiempo de inferencia 40.82 ms
#   Se detectaron 12 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment29
#   Tiempo de inferencia 43.4 ms
#   Se detectaron 14 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment29
#   Tiempo de inferencia 33.85 ms
#   Se detectaron 13 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment29
#   Tiempo de inferencia 42.06 ms
#   Se detectaron 35 objetos plant-weed.
#
# ❇️ Procesado 18.52%
#
# INFERENCE 10/54:
#  tile01x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment210
#   Tiempo de inferencia 46.44 ms
#   Se detectaron 61 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment210
#   Tiempo de inferencia 51.5 ms
#   Se detectaron 75 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment210
#   Tiempo de inferencia 45.42 ms
#   Se detectaron 68 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment210
#   Tiempo de inferencia 80.79 ms
#   Se detectaron 169 objetos plant-weed.
#
# ❇️ Procesado 20.37%
#
# INFERENCE 11/54:
#  tile01x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment211
#   Tiempo de inferencia 52.41 ms
#   Se detectaron 81 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment211
#   Tiempo de inferencia 53.72 ms
#   Se detectaron 104 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment211
#   Tiempo de inferencia 50.33 ms
#   Se detectaron 88 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment211
#   Tiempo de inferencia 69.89 ms
#   Se detectaron 166 objetos plant-weed.
#
# ❇️ Procesado 22.22%
#
# INFERENCE 12/54:
#  tile01x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment212
#   Tiempo de inferencia 42.37 ms
#   Se detectaron 54 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment212
#   Tiempo de inferencia 47.7 ms
#   Se detectaron 66 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment212
#   Tiempo de inferencia 44.86 ms
#   Se detectaron 58 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment212
#   Tiempo de inferencia 58.83 ms
#   Se detectaron 111 objetos plant-weed.
#
# ❇️ Procesado 24.07%
#
# INFERENCE 13/54:
#  tile01x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment213
#   Tiempo de inferencia 43.22 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment213
#   Tiempo de inferencia 44.67 ms
#   Se detectaron 49 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment213
#   Tiempo de inferencia 44.07 ms
#   Se detectaron 58 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment213
#   Tiempo de inferencia 57.32 ms
#   Se detectaron 94 objetos plant-weed.
#
# ❇️ Procesado 25.93%
#
# INFERENCE 14/54:
#  tile01x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment214
#   Tiempo de inferencia 47.23 ms
#   Se detectaron 31 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment214
#   Tiempo de inferencia 47.26 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment214
#   Tiempo de inferencia 44.16 ms
#   Se detectaron 50 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment214
#   Tiempo de inferencia 52.57 ms
#   Se detectaron 76 objetos plant-weed.
#
# ❇️ Procesado 27.78%
#
# INFERENCE 15/54:
#  tile01x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment215
#   Tiempo de inferencia 39.4 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment215
#   Tiempo de inferencia 41.23 ms
#   Se detectaron 32 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment215
#   Tiempo de inferencia 38.75 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment215
#   Tiempo de inferencia 58.74 ms
#   Se detectaron 53 objetos plant-weed.
#
# ❇️ Procesado 29.63%
#
# INFERENCE 16/54:
#  tile01x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment216
#   Tiempo de inferencia 41.68 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment216
#   Tiempo de inferencia 50.0 ms
#   Se detectaron 47 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment216
#   Tiempo de inferencia 83.07 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment216
#   Tiempo de inferencia 81.33 ms
#   Se detectaron 85 objetos plant-weed.
#
# ❇️ Procesado 31.48%
#
# INFERENCE 17/54:
#  tile01x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment217
#   Tiempo de inferencia 40.41 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment217
#   Tiempo de inferencia 41.68 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment217
#   Tiempo de inferencia 43.38 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment217
#   Tiempo de inferencia 51.2 ms
#   Se detectaron 55 objetos plant-weed.
#
# ❇️ Procesado 33.33%
#
# INFERENCE 18/54:
#  tile01x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment218
#   Tiempo de inferencia 35.73 ms
#   Se detectaron 14 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment218
#   Tiempo de inferencia 38.33 ms
#   Se detectaron 16 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment218
#   Tiempo de inferencia 41.06 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment218
#   Tiempo de inferencia 45.88 ms
#   Se detectaron 38 objetos plant-weed.
#
# ❇️ Procesado 35.19%
#
# INFERENCE 19/54:
#  tile02x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment219
#   Tiempo de inferencia 52.1 ms
#   Se detectaron 56 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment219
#   Tiempo de inferencia 64.12 ms
#   Se detectaron 59 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment219
#   Tiempo de inferencia 49.34 ms
#   Se detectaron 63 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment219
#   Tiempo de inferencia 63.88 ms
#   Se detectaron 141 objetos plant-weed.
#
# ❇️ Procesado 37.04%
#
# INFERENCE 20/54:
#  tile02x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment220
#   Tiempo de inferencia 41.94 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment220
#   Tiempo de inferencia 46.13 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment220
#   Tiempo de inferencia 44.91 ms
#   Se detectaron 50 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment220
#   Tiempo de inferencia 64.02 ms
#   Se detectaron 83 objetos plant-weed.
#
# ❇️ Procesado 38.89%
#
# INFERENCE 21/54:
#  tile02x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment221
#   Tiempo de inferencia 47.03 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment221
#   Tiempo de inferencia 48.64 ms
#   Se detectaron 47 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment221
#   Tiempo de inferencia 45.57 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment221
#   Tiempo de inferencia 55.87 ms
#   Se detectaron 84 objetos plant-weed.
#
# ❇️ Procesado 40.74%
#
# INFERENCE 22/54:
#  tile02x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment222
#   Tiempo de inferencia 44.61 ms
#   Se detectaron 48 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment222
#   Tiempo de inferencia 47.11 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment222
#   Tiempo de inferencia 44.78 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment222
#   Tiempo de inferencia 54.32 ms
#   Se detectaron 78 objetos plant-weed.
#
# ❇️ Procesado 42.59%
#
# INFERENCE 23/54:
#  tile02x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment223
#   Tiempo de inferencia 48.26 ms
#   Se detectaron 56 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment223
#   Tiempo de inferencia 51.6 ms
#   Se detectaron 60 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment223
#   Tiempo de inferencia 50.57 ms
#   Se detectaron 52 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment223
#   Tiempo de inferencia 66.2 ms
#   Se detectaron 90 objetos plant-weed.
#
# ❇️ Procesado 44.44%
#
# INFERENCE 24/54:
#  tile02x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment224
#   Tiempo de inferencia 55.89 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment224
#   Tiempo de inferencia 49.52 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment224
#   Tiempo de inferencia 43.16 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment224
#   Tiempo de inferencia 60.27 ms
#   Se detectaron 94 objetos plant-weed.
#
# ❇️ Procesado 46.30%
#
# INFERENCE 25/54:
#  tile02x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment225
#   Tiempo de inferencia 43.65 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment225
#   Tiempo de inferencia 48.85 ms
#   Se detectaron 52 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment225
#   Tiempo de inferencia 45.93 ms
#   Se detectaron 55 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment225
#   Tiempo de inferencia 58.62 ms
#   Se detectaron 83 objetos plant-weed.
#
# ❇️ Procesado 48.15%
#
# INFERENCE 26/54:
#  tile02x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment226
#   Tiempo de inferencia 52.57 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment226
#   Tiempo de inferencia 47.91 ms
#   Se detectaron 54 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment226
#   Tiempo de inferencia 48.78 ms
#   Se detectaron 58 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment226
#   Tiempo de inferencia 69.88 ms
#   Se detectaron 102 objetos plant-weed.
#
# ❇️ Procesado 50.00%
#
# INFERENCE 27/54:
#  tile02x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment227
#   Tiempo de inferencia 42.58 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment227
#   Tiempo de inferencia 45.48 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment227
#   Tiempo de inferencia 40.06 ms
#   Se detectaron 41 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment227
#   Tiempo de inferencia 53.76 ms
#   Se detectaron 87 objetos plant-weed.
#
# ❇️ Procesado 51.85%
#
# INFERENCE 28/54:
#  tile03x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment228
#   Tiempo de inferencia 41.74 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment228
#   Tiempo de inferencia 44.79 ms
#   Se detectaron 62 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment228
#   Tiempo de inferencia 42.64 ms
#   Se detectaron 60 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment228
#   Tiempo de inferencia 61.49 ms
#   Se detectaron 130 objetos plant-weed.
#
# ❇️ Procesado 53.70%
#
# INFERENCE 29/54:
#  tile03x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment229
#   Tiempo de inferencia 47.21 ms
#   Se detectaron 59 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment229
#   Tiempo de inferencia 47.85 ms
#   Se detectaron 57 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment229
#   Tiempo de inferencia 49.55 ms
#   Se detectaron 65 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment229
#   Tiempo de inferencia 62.04 ms
#   Se detectaron 132 objetos plant-weed.
#
# ❇️ Procesado 55.56%
#
# INFERENCE 30/54:
#  tile03x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment230
#   Tiempo de inferencia 49.58 ms
#   Se detectaron 75 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment230
#   Tiempo de inferencia 51.52 ms
#   Se detectaron 70 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment230
#   Tiempo de inferencia 47.6 ms
#   Se detectaron 71 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment230
#   Tiempo de inferencia 62.23 ms
#   Se detectaron 121 objetos plant-weed.
#
# ❇️ Procesado 57.41%
#
# INFERENCE 31/54:
#  tile03x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment231
#   Tiempo de inferencia 58.79 ms
#   Se detectaron 65 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment231
#   Tiempo de inferencia 49.01 ms
#   Se detectaron 64 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment231
#   Tiempo de inferencia 46.88 ms
#   Se detectaron 57 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment231
#   Tiempo de inferencia 66.36 ms
#   Se detectaron 124 objetos plant-weed.
#
# ❇️ Procesado 59.26%
#
# INFERENCE 32/54:
#  tile03x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment232
#   Tiempo de inferencia 44.23 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment232
#   Tiempo de inferencia 45.26 ms
#   Se detectaron 52 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment232
#   Tiempo de inferencia 41.27 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment232
#   Tiempo de inferencia 55.05 ms
#   Se detectaron 95 objetos plant-weed.
#
# ❇️ Procesado 61.11%
#
# INFERENCE 33/54:
#  tile03x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment233
#   Tiempo de inferencia 41.8 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment233
#   Tiempo de inferencia 43.7 ms
#   Se detectaron 43 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment233
#   Tiempo de inferencia 41.73 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment233
#   Tiempo de inferencia 61.72 ms
#   Se detectaron 78 objetos plant-weed.
#
# ❇️ Procesado 62.96%
#
# INFERENCE 34/54:
#  tile03x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment234
#   Tiempo de inferencia 47.84 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment234
#   Tiempo de inferencia 43.27 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment234
#   Tiempo de inferencia 45.85 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment234
#   Tiempo de inferencia 52.61 ms
#   Se detectaron 61 objetos plant-weed.
#
# ❇️ Procesado 64.81%
#
# INFERENCE 35/54:
#  tile03x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment235
#   Tiempo de inferencia 45.4 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment235
#   Tiempo de inferencia 43.37 ms
#   Se detectaron 45 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment235
#   Tiempo de inferencia 41.37 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment235
#   Tiempo de inferencia 54.66 ms
#   Se detectaron 97 objetos plant-weed.
#
# ❇️ Procesado 66.67%
#
# INFERENCE 36/54:
#  tile03x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment236
#   Tiempo de inferencia 38.78 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment236
#   Tiempo de inferencia 40.05 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment236
#   Tiempo de inferencia 49.06 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment236
#   Tiempo de inferencia 52.3 ms
#   Se detectaron 81 objetos plant-weed.
#
# ❇️ Procesado 68.52%
#
# INFERENCE 37/54:
#  tile04x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment237
#   Tiempo de inferencia 38.95 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment237
#   Tiempo de inferencia 39.91 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment237
#   Tiempo de inferencia 40.56 ms
#   Se detectaron 41 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment237
#   Tiempo de inferencia 53.03 ms
#   Se detectaron 83 objetos plant-weed.
#
# ❇️ Procesado 70.37%
#
# INFERENCE 38/54:
#  tile04x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment238
#   Tiempo de inferencia 39.69 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment238
#   Tiempo de inferencia 41.45 ms
#   Se detectaron 36 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment238
#   Tiempo de inferencia 40.36 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment238
#   Tiempo de inferencia 50.59 ms
#   Se detectaron 72 objetos plant-weed.
#
# ❇️ Procesado 72.22%
#
# INFERENCE 39/54:
#  tile04x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment239
#   Tiempo de inferencia 46.42 ms
#   Se detectaron 61 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment239
#   Tiempo de inferencia 55.31 ms
#   Se detectaron 75 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment239
#   Tiempo de inferencia 58.3 ms
#   Se detectaron 63 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment239
#   Tiempo de inferencia 69.29 ms
#   Se detectaron 142 objetos plant-weed.
#
# ❇️ Procesado 74.07%
#
# INFERENCE 40/54:
#  tile04x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment240
#   Tiempo de inferencia 46.04 ms
#   Se detectaron 71 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment240
#   Tiempo de inferencia 51.01 ms
#   Se detectaron 84 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment240
#   Tiempo de inferencia 53.11 ms
#   Se detectaron 83 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment240
#   Tiempo de inferencia 69.17 ms
#   Se detectaron 148 objetos plant-weed.
#
# ❇️ Procesado 75.93%
#
# INFERENCE 41/54:
#  tile04x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment241
#   Tiempo de inferencia 62.34 ms
#   Se detectaron 44 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment241
#   Tiempo de inferencia 70.0 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment241
#   Tiempo de inferencia 52.31 ms
#   Se detectaron 58 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment241
#   Tiempo de inferencia 61.39 ms
#   Se detectaron 104 objetos plant-weed.
#
# ❇️ Procesado 77.78%
#
# INFERENCE 42/54:
#  tile04x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment242
#   Tiempo de inferencia 45.86 ms
#   Se detectaron 51 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment242
#   Tiempo de inferencia 46.39 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment242
#   Tiempo de inferencia 45.38 ms
#   Se detectaron 53 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment242
#   Tiempo de inferencia 60.82 ms
#   Se detectaron 104 objetos plant-weed.
#
# ❇️ Procesado 79.63%
#
# INFERENCE 43/54:
#  tile04x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment243
#   Tiempo de inferencia 44.56 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment243
#   Tiempo de inferencia 47.21 ms
#   Se detectaron 50 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment243
#   Tiempo de inferencia 50.05 ms
#   Se detectaron 55 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment243
#   Tiempo de inferencia 64.07 ms
#   Se detectaron 86 objetos plant-weed.
#
# ❇️ Procesado 81.48%
#
# INFERENCE 44/54:
#  tile04x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment244
#   Tiempo de inferencia 51.22 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment244
#   Tiempo de inferencia 47.38 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment244
#   Tiempo de inferencia 48.03 ms
#   Se detectaron 54 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment244
#   Tiempo de inferencia 59.0 ms
#   Se detectaron 95 objetos plant-weed.
#
# ❇️ Procesado 83.33%
#
# INFERENCE 45/54:
#  tile04x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment245
#   Tiempo de inferencia 43.01 ms
#   Se detectaron 42 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment245
#   Tiempo de inferencia 46.98 ms
#   Se detectaron 46 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment245
#   Tiempo de inferencia 42.57 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment245
#   Tiempo de inferencia 58.7 ms
#   Se detectaron 111 objetos plant-weed.
#
# ❇️ Procesado 85.19%
#
# INFERENCE 46/54:
#  tile05x00.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment246
#   Tiempo de inferencia 37.61 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment246
#   Tiempo de inferencia 39.31 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment246
#   Tiempo de inferencia 40.85 ms
#   Se detectaron 24 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment246
#   Tiempo de inferencia 52.89 ms
#   Se detectaron 49 objetos plant-weed.
#
# ❇️ Procesado 87.04%
#
# INFERENCE 47/54:
#  tile05x01.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment247
#   Tiempo de inferencia 43.8 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment247
#   Tiempo de inferencia 45.73 ms
#   Se detectaron 35 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment247
#   Tiempo de inferencia 44.97 ms
#   Se detectaron 40 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment247
#   Tiempo de inferencia 60.03 ms
#   Se detectaron 74 objetos plant-weed.
#
# ❇️ Procesado 88.89%
#
# INFERENCE 48/54:
#  tile05x02.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment248
#   Tiempo de inferencia 42.65 ms
#   Se detectaron 30 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment248
#   Tiempo de inferencia 43.44 ms
#   Se detectaron 28 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment248
#   Tiempo de inferencia 43.49 ms
#   Se detectaron 38 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment248
#   Tiempo de inferencia 54.33 ms
#   Se detectaron 62 objetos plant-weed.
#
# ❇️ Procesado 90.74%
#
# INFERENCE 49/54:
#  tile05x03.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment249
#   Tiempo de inferencia 38.97 ms
#   Se detectaron 23 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment249
#   Tiempo de inferencia 185.5 ms
#   Se detectaron 25 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment249
#   Tiempo de inferencia 56.51 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment249
#   Tiempo de inferencia 82.9 ms
#   Se detectaron 66 objetos plant-weed.
#
# ❇️ Procesado 92.59%
#
# INFERENCE 50/54:
#  tile05x04.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment250
#   Tiempo de inferencia 49.27 ms
#   Se detectaron 33 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment250
#   Tiempo de inferencia 54.6 ms
#   Se detectaron 39 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment250
#   Tiempo de inferencia 52.4 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment250
#   Tiempo de inferencia 70.8 ms
#   Se detectaron 80 objetos plant-weed.
#
# ❇️ Procesado 94.44%
#
# INFERENCE 51/54:
#  tile05x05.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment251
#   Tiempo de inferencia 55.64 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment251
#   Tiempo de inferencia 46.42 ms
#   Se detectaron 14 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment251
#   Tiempo de inferencia 42.22 ms
#   Se detectaron 18 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment251
#   Tiempo de inferencia 56.58 ms
#   Se detectaron 49 objetos plant-weed.
#
# ❇️ Procesado 96.30%
#
# INFERENCE 52/54:
#  tile05x06.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment252
#   Tiempo de inferencia 46.55 ms
#   Se detectaron 27 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment252
#   Tiempo de inferencia 48.46 ms
#   Se detectaron 32 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment252
#   Tiempo de inferencia 45.92 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment252
#   Tiempo de inferencia 55.48 ms
#   Se detectaron 48 objetos plant-weed.
#
# ❇️ Procesado 98.15%
#
# INFERENCE 53/54:
#  tile05x07.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment253
#   Tiempo de inferencia 50.88 ms
#   Se detectaron 21 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment253
#   Tiempo de inferencia 60.38 ms
#   Se detectaron 34 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment253
#   Tiempo de inferencia 54.02 ms
#   Se detectaron 37 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment253
#   Tiempo de inferencia 60.38 ms
#   Se detectaron 55 objetos plant-weed.
#
# ❇️ Procesado 100.00%
#
# INFERENCE 54/54:
#  tile05x08.503_222_54.640px.jpg
#
# Proyecto: model0
# Results saved to model0/experiment254
#   Tiempo de inferencia 42.5 ms
#   Se detectaron 22 objetos plant-weed.
#
# Proyecto: model1
# Results saved to model1/experiment254
#   Tiempo de inferencia 49.85 ms
#   Se detectaron 19 objetos plant-weed.
#
# Proyecto: model2
# Results saved to model2/experiment254
#   Tiempo de inferencia 49.79 ms
#   Se detectaron 29 objetos plant-weed.
#
# Proyecto: model3
# Results saved to model3/experiment254
#   Tiempo de inferencia 107.5 ms
#   Se detectaron 65 objetos plant-weed.
#
# ✅ EJECUCIÓN COMPLETA
#
# Totales por modelo:
#   Modelo 1 (7.50 seg): 2139
#   Modelo 2 (3.37 seg): 2330
#   Modelo 3 (3.10 seg): 2388
#   Modelo 4 (3.66 seg): 4709

# %%
count_avg = df_count.mean().values
time_avg = df_time.mean().values

print("Promedios por modelo:")
for index, (time_, count_) in enumerate(zip(time_avg, count_avg)):
    print(f"  Modelo {index + 1} ({float(time_*1000):.3f} ms): {float(count_):.1f} obj/image")
print()
# Out:
# Promedios por modelo:
#   Modelo 1 (138.859 ms): 39.6 obj/image
#   Modelo 2 (62.466 ms): 43.1 obj/image
#   Modelo 3 (57.467 ms): 44.2 obj/image
#   Modelo 4 (67.803 ms): 87.2 obj/image

# %% [markdown]
# # Almacenamiento de predicciones

# %%
# Store experiments
# !mkdir /content/drive/MyDrive/Results
for index, model in enumerate(models):
    project= f"model{index}"
    save_on_cloud(source=f'/content/{project}/{experiment}/', destination=f'/content/drive/MyDrive/Results/{project}/{experiment}/')
    print()
# Out:
# ✅ Folder copied successfully:
#    /content/model0/experiment1/
#   --> /content/drive/MyDrive/Results/model0/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model1/experiment1/
#   --> /content/drive/MyDrive/Results/model1/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model2/experiment1/
#   --> /content/drive/MyDrive/Results/model2/experiment1/
#
# ✅ Folder copied successfully:
#    /content/model3/experiment1/
#   --> /content/drive/MyDrive/Results/model3/experiment1/

# %%
# Save execution time log
filenames = [{
    'file': df_time,
    'name': f"{experiment}.total_time.csv"},
     {'file': df_count,
    'name': f"{experiment}.total_count.csv"}
  ]

for filename in filenames:
  try:
      name = filename['name']
      df = filename['file']
      if df is not None:
        df.to_csv(f"/content/{name}")
      print(f"✅ Execution log saved as CSV to {name}")

      source=f'/content/{name}'
      destination='/content/drive/MyDrive/Results/'
      # !cp $source $destination

  except PermissionError:
      print(f"Error: Permission denied. Could not save {name}")
  except OSError as e:
      print(f"Error: An operating system error occurred: {e} when trying to save {name}.")
  except Exception as e:
      print(f"An unexpected error occurred: {e} when trying to save {name}.")
# Out:
# ✅ Execution log saved as CSV to experiment2.total_time.csv
# ✅ Execution log saved as CSV to experiment2.total_count.csv

# %% [markdown]
# # Eliminar archivos de inferencia (en caso de errores)

# %%
proceed = False

# %%
# Removes pervious train (CAUTION)
if proceed:
  for index, model in enumerate(models):
      project= f"model{index}"
      source=f'/content/{project}/'
      # !rm -rf $source

# %%
if proceed:
  file = f"/content/{experiment}.total_count.csv"
  # !rm $file
  file = f"/content/{experiment}.total_time.csv"
  # !rm $file
